# %% [markdown]
# # Sandbox environment for testing WGAN-GP on timeseries data

# %% [markdown]
# ## Import libraries and configure Jupyter Notebook environment

# %%
# Import lib and config notebook with `DataAnalyst package`
#from DataAnalyst.utils.libraries import * #load all packages into JN
from DataAnalyst import IPythonConfig
IPythonConfig.config_jedi()
IPythonConfig.set_cwd()
IPythonConfig.set_autoreload()
IPythonConfig.config_libs()

# Tensorflow
import tensorflow as tf 
import tensorflow.keras as tfk

# Sklearn
from sklearn.model_selection import train_test_split
# Out:
# Working directory: C:\Users\ilias\Desktop\Stress Testing with GANs-Gdrive\Stress Testing with GANs\IRRBB

# %%
# Import in-house modules
# -------------------------
from src.mdl import GANBase
from src.utils.nnvis import GANvis
from src.utils.toydata_generator import dataGenerator
from src.utils.parser import Parser

# %% [markdown]
# # Test out Generator

# %% [markdown]
# ## Generate the "real" dataset
#
# The real dataset is a bivariate `Gaussian` dataset with samples being drawn from:
# $$
# N~(\mu = [10, 10], \begin{bmatrix}
#                     1 & 0 \\
#                     0 & 1
#                     \end{bmatrix})
# $$

# %%
# Create "real" dataset
n, v= 1000, 2
distribution= "multivariate Gaussian"
mu, std= [2, 2], [[1, 0.7], [0.7, 1]]
Pr = dataGenerator.generate_data(n, v, distribution, loc= mu, scale= std)
Pr.head()
# Out:
#    feature_1  feature_2
# 0       2.94       2.18
# 1       2.57       2.26
# 2       1.70       1.19
# 3       1.19       0.63
# 4       3.34       3.40

# %% [markdown]
# ## Drawing from our untrained `Generator`
#
# Let's now initialize our `GAN` model and draw samples from the untrained `Generator` and compare the samples with the ones coming from the real dataset.
#
# We see that the original dataset has an elliptical distribution.
#
# text ...

# %%
# Init base class of GAN
gan= GANBase(Pr)
gan.init_discriminator(output_activation=tfk.activations.sigmoid)
gan.init_generator()
# Sample real and generated data
Pr_sampled= gan.generate_data('Pr', n= 1000, as_df= True)
Pg_sampled= gan.generate_data('Pg', n= 1000, as_df= True)
# Plot samples
GANvis.plot_scatter(data= (Pr_sampled, Pg_sampled)).show(config= GANvis.config)
# Out:
# <div>                            <div id="0e667fcd-d454-4af6-be4a-8590ef6ddc3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e667fcd-d454-4af6-be4a-8590ef6ddc3b")) {                    Plotly.newPlot(                        "0e667fcd-d454-4af6-be4a-8590ef6ddc3b",                        [{"hovertemplate":"=Pr<br>feature_1=%{x}<br>feature_2=%{y}<extra></extra>","legendgroup":"Pr","marker":{"color":"#F8766D","symbol":"circle"},"mode":"markers","name":"Pr","showlegend":true,"type":"scattergl","x":[2.943359375,2.5703125,1.705078125,1.19140625,3.3359375,3.4140625,2.1171875,0.300537109375,3.26953125,4.875,1.79296875,1.7646484375,1.4765625,2.2421875,1.2158203125,1.28515625,1.439453125,2.388671875,2.5,1.669921875,1.9052734375,1.60546875,3.447265625,2.3515625,0.72216796875,2.185546875,1.0458984375,2.01171875,1.38671875,0.0911865234375,3.48828125,2.029296875,2.505859375,1.48046875,1.5146484375,0.79248046875,2.08203125,1.6689453125,2.052734375,2.35546875,1.1484375,0.93505859375,-0.431640625,
4.58984375,2.291015625,1.875,2.630859375,1.78515625,1.46484375,1.560546875,1.193359375,1.3876953125,0.75537109375,1.955078125,1.8486328125,1.9072265625,2.62890625,3.5546875,2.6328125,2.67578125,0.95361328125,1.9345703125,1.9423828125,2.22265625,2.4453125,2.87109375,2.552734375,3.1328125,2.3203125,1.4990234375,1.5390625,2.84375,2.6171875,2.537109375,0.08001708984375,2.591796875,2.197265625,2.228515625,4.1796875,1.7294921875,2.1796875,1.685546875,2.787109375,1.5107421875,0.98779296875,1.490234375,3.0,1.841796875,1.939453125,1.4716796875,-0.292724609375,1.7802734375,1.404296875,3.1640625,2.908203125,3.55078125,3.47265625,0.3173828125,3.095703125,0.7236328125,2.03515625,2.125,1.3544921875,1.8515625,2.349609375,2.689453125,1.4736328125,1.91015625,0.64306640625,2.337890625,2.818359375,2.794921875,2.9453125,4.47265625,1.53515625,1.67578125,1.0556640625,2.849609375,1.1337890625,3.15625,4.5703125,1.0517578125,1.763671875,0.296142578125,1.4873046875 ...

# %%
# Train the Discriminator now for a couple of epochs
# Create train and test split 
xtrain, xtest, ytrain, ytest= train_test_split(X, y, test_size= 0.25, random_state=0)
# Train Discriminator
gan.D.compile(loss='BinaryCrossentropy', metrics= ['Accuracy'])
gan.D.fit(x= xtrain, y= ytrain, epochs= 10)
# Out:
# Epoch 1/10
# 47/47 [==============================] - 3s 6ms/step - loss: 0.3749 - Accuracy: 0.8753
# Epoch 2/10
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1695 - Accuracy: 0.9567
# Epoch 3/10
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1325 - Accuracy: 0.9600
# Epoch 4/10
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1279 - Accuracy: 0.9633
# Epoch 5/10
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1259 - Accuracy: 0.9640
# Epoch 6/10
# 47/47 [==============================] - 0s 4ms/step - loss: 0.1238 - Accuracy: 0.9613
# Epoch 7/10
# 47/47 [==============================] - 0s 6ms/step - loss: 0.1212 - Accuracy: 0.9640
# Epoch 8/10
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1205 - Accuracy: 0.9633
# Epoch 9/10
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1189 - Accuracy: 0.9633
# Epoch 10/10
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1183 - Accuracy: 0.9620

# %% [markdown]
# # Test out WGAN-GP

# %%
from src.model.wgan_gp import WGANGP

# %%
wgan = WGANGP(D= gan.D, G= gan.G)

# %%
type(Pr_sampled)
# Out:
# pandas.core.frame.DataFrame

# %%
wgan.get_GP(Pr_sampled.iloc[:10, :], Pg_sampled.iloc[:10, :]).numpy()
# Out:
# 0.9008168

# %%
gan.D.summary()
# Out:
# Model: "Discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 2)]               0
#
#  hidden_layer_1 (Dense)      (None, 64)                192
#
#  hidden_layer_2 (Dense)      (None, 32)                2080
#
#  hidden_layer_3 (Dense)      (None, 16)                528
#
#  output_layer (Dense)        (None, 1)                 17
#
# =================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________
